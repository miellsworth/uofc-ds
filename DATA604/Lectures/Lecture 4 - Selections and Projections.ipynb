# %% [markdown]
# ## Introduction
#
# This notebook will introduce the concept of selecting sets of rows and columns in each of pandas, an SQL table, and a NoSQL collecion.
#
# Along the way, you will learn some methods for interacting with SQL and NoSQL in MySQL.

# %% [markdown]
# ## What you already know
#
# Using DataFrames, you're already well-versed in filtering your data to produce a subset of columns or rows.
#
# For example, you can work with the provided csv, Calgary_Public_Library_Locations_and_Hours.csv.
#
# Open it now using pandas.

# %%
import pandas as pd

cpl_locations = pd.read_csv("Calgary_Public_Library_Locations_and_Hours.csv")
cpl_locations.head()
# Out:
#                         Library Postal_Code  Square_Feet  Phone_Number  \
# 0  W.R. Castell Central Library     T2G 2M2       177532  403-260-2600
# 1     Alexander Calhoun Library     T2T 3V8         9256  403-260-2600
# 2               Bowness Library     T3B 0H3         7800  403-260-2600
# 3            Fish Creek Library     T2J 6S1        47074  403-260-2600
# 4           Forest Lawn Library     T2A 4M1        16977  403-260-2600
#
#   Monday_Open Monday_Close Tuesday_Open Tuesday_Close Wednesday_Open  \
# 0        9:00        20:00         9:00         20:00           9:00
# 1       10:00        21:00        10:00         21:00          10:00
# 2       13:00        20:00        10:00         20:00          10:00
# 3        9:00        21:00         9:00         21:00           9:00
# 4       10:00        21:00        10:00         21:00          10:00
#
#   Wednesday_Close Thursday_Open Thursday_Close Friday_Open Friday_Close  \
# 0           20:00          9:00          20:00        9:00        17:00
# 1           21:00         10:00          21:00       10:00        18:00
# 2           20:00         10:00          17:00       10:00        17:00
# 3           21:00          9:00          21:00        9:00        18:00
# 4           21:00         10:00          21:00       10:00        18:00
#
#   Saturday_Open Saturday_Close Sunday_Open Sunday_Close  \
# 0         10:00          17:00       12:00        17:00
# 1         10:00          17:00       12:00        17:00
# 2         10:00          17:00       12:00        17:00
# 3          9:00          17:00       12:00        17:00
# 4         10:00          17:00       12:00        17:00
#
#                                              Address
# 0      616 Macleod Tr SE\n(51.0470276, -114.0578995)
# 1          3223 14 St SW\n(51.0255318, -114.0947876)
# 2     7930 Bowness Rd NW\n(51.0872841, -114.1830978)
# 3  11161 Bonaventure Dr SE\n(50.9516296, -114.060...
# 4            4807 8 Av SE\n(51.045105, -113.9652023)

# %% [markdown]
# Now for some practice filtering subsets of rows (projections) and columns (selections).
#
# In the code block below, write code for:
# - the subset of rows for all libraries which are open at 9:00 AM on Fridays.
# - the subset of rows for all libraries under 8000 square feet in area
# - the subset of columns consisting of the library name, the address, and the postal code

# %%
# your pandas code should go here

# %% [markdown]
# ## Getting set up to use mySQL
#
# To connect to your mysql database, you will need a *connector*. There are many of these available, but we will be using [`mysql-connector-python,`](https://anaconda.org/anaconda/mysql-connector-python]) as one of the most common and well-documented ways to connect to MySql. You may need to install the connector first.
#
# Use the following command in your Jupyter terminal:
#
# `pip install mysql-connector-python`
# or
# `conda install mysql-connector-python`
#
# (If you have followed our previous instructions on how to set up mySQL, this should already be done)

# %% [markdown]
# ## <a name = "createdb"></a> Create and populate a database table
#
# You should have a database named `test` as part of your setup (we had you create it). We will use this for now.
#
# Now we'll create a table using the MySQL shell. We can do this using Python, but we want you to have some familiarity with the MySQL shell as well.
#
# Use the file named `create_libraries.sql` to do so. Be sure to open it in a text editor beforehand to check what it does.
#
# To use `create_libraries.sql`, from the MySQL shell, do the following:
# - use sql mode (`\sql`)
# - connect to your database if you aren't already connected (`\connect root@localhost:33060`)
# - select your schema (`\use test`)
# - use the command (`\. "<PATH TO FILE>\create_libraries.sql";` or `\source "PATH TO FILE\create_libraries.sql";\`) to get MySQL to read the contents of the file and run it
# - you may use `show tables;` and `describe library_locations;` to verify that everything has run correctly
#
# Now we are going to insert some data into the table. We start by connecting to the database.

# %%
import mysql.connector

# fill in any relevant details that need to be changed here, such as if you set up a different user or password
myconnection = mysql.connector.connect(user='root', password='Leftw!ng6977',
                                 host='127.0.0.1',
                                 database='test')

# %% [markdown]
# The next step is to load data into the table. There are again many approaches, but we note that the data has already been loaded into a DataFrame.
#
# The first thing we need is something to hold our place in the table, commonly called a cursor.

# %%
insertCursor = myconnection.cursor()

columnString = "`,`".join([str(currentColumn) for currentColumn in cpl_locations.columns.tolist()])
#print (columnString)

# inserting rows one by one from the DataFrame is sufficient for now
for i, currentRow in cpl_locations.iterrows():
    #print (tuple(currentRow))
    insertCommand = "INSERT INTO `library_locations` (`" + columnString + "`) VALUES (" + "%s,"*(len(currentRow)-1) + "%s)"
    #print (insertCommand)
    insertCursor.execute(insertCommand, tuple(currentRow))
    
myconnection.commit()
myconnection.close()

# %% [markdown]
# Should you need to reset your database at any point in time, use the following SQL command to drop the table:
# `DROP TABLE library_locations;`
#
# Then [return to the notebook cell](#createdb) about creating a table and follow the notebook to the point where data has been inserted again.

# %% [markdown]
# ## Querying a database table
#
# The structure of a SQL is relatively simple.
#
# SELECT {COLUMNS} FROM {TABLE} WHERE {conditions}
#
# For example, to select the branch names and addresses from our library_location table, we would use:
#
# `SELECT Library, Address FROM library_location`
#
# A query which selects a subset of columns from a table is called a _projection_.
#
# A query which selects a subset of rows from a table is called a _selection_.
#
# The following query is a selection of all rows of libraries with the word "Hill" in their library name.
#
# `SELECT * from library_locations where Library LIKE '%hill%';`
#
# You will notice that SQL is not particularly case sensitive.

# %% [markdown]
# Now from the MySQL shell, write queries in the shell for the following:
# - the subset of columns consisting of the library name, and the phone number
# - the subset of rows for all libraries which are open at 12:00 PM on Sundays. (_Hint: you should be able to use = for equality_)
# - the subset of rows for all libraries over 12000 square feet in area (_Hint: you should be able to use < and > with numbers_)
#
# Include your queries in the Markdown Cell below for posterity.

# %% [markdown]
# SELECT Library FROM library_locations WHERE Sunday_Open = '12:00';
# SELECT Library, Sunday_Open FROM library_locations WHERE Sunday_Open = '12:00';
# SELECT Library, Square_Feet FROM library_locations WHERE Square_Feet>12000;

# %% [markdown]
# ## Using NoSQL for queries
#
# The first thing we're going to do is load a DataFrame from a JSON file, and get comfortable with the data.

# %%
# JSON: load a DataFrame from JSON

import json

# There are different ways to parse JSON files for DataFrames, but some 
# experimentation may be needed to get your file into the right shape. 

# I encourage you to play around with the lines below to see how this code 
# took shape

with open("canadianCheeseDirectory.json", encoding="UTF-8") as cheeseDirectory:
    inputList = json.load(cheeseDirectory)

# print (inputList)    
    
cheeseFrame = pd.DataFrame.from_dict(inputList)
cheeseFrame = cheeseFrame.CheeseDirectory.dropna().apply(pd.Series)

display(cheeseFrame)
# Out:
#      CheeseId                                     CheeseNameEn  \
# 0         228
# 1         242
# 2         301               Provolone Sette Fette (Tre-Stelle)
# 3         303
# 4         319
# 5         350             Paneer (Northumberland Co-operative)
# 6         374                             Goat Brie (Woolwich)
# 7         375                          Goat Cheddar (Woolwich)
# 8         376                        Goat Mozarella (Woolwich)
# 9         378                             Goat Feta (Woolwich)
# 10        379
# 11        406                                      Leoni-Grana
# 12        414                       Gouda (Jerseyland Organic)
# 13        415                     Cheddar (Jerseyland Organic)
# 14        416                       Grana (Jerseyland Organic)
# 15        417                        Feta (Jerseyland Organic)
# 16        418  Udderly Organic Goat Gouda (Jerseyland Organic)
# 17        419   Udderly Organic Goat Feta (Jerseyland Organic)
# 18        624                                        Madawaska
# 19        629                         Cracked Pepper Verdelait
# 20        630                                  Cumin Verdelait
# 21        631                       Garlic and Chive Verdelait
# 22        632                                 Wasabi Verdelait
# 23        648                                  Comox Camembert
# 24        655                               Provolone (Silani)
# 25        656                                 Ricotta (Silani)
# 26        657                         Gouda (Sylvan Star Ltd.)
# 27        658                                     Niagara Gold
# 28        659                                    Comfort Cream
# 29        662                              Cheddar (Balderson)
# ...       ...                                              ...
# 1421     2362
# 1422     2363
# 1423     2364
# 1424     2365
# 1425     2366
# 1426     2367
# 1427     2368
# 1428     2369
# 1429     2370
# 1430     2371
# 1431     2372                                 Traditional Feta
# 1432     2373                                        Louis Cyr
# 1433     2374       Cheddar (Biobio) - Mild, medium and strong
# 1434     2375                                   Gouda (Biobio)
# 1435     2376          Coteau Hills Creamery Balkan Feta Style
# 1436     2377                                     Dill Cheddar
# 1437     2378                                   Garlic Cheddar
# 1438     2379                                     Cheese Curds
# 1439     2380                 Smoky/Smoke Cheddar (Apple Wood)
# 1440     2381                                           Cancre
# 1441     2382                                          Brigand
# 1442     2383                                         Gavroche
# 1443     2384           Petit frais aux noix et sirop d'érable
# 1444     2385                                   Petits caprice
# 1445     2386                      Petit frais aux canneberges
# 1446     2387                                         Knoydart
# 1447     2388                                          FRESK-O
# 1448     2389                                    Electric Blue
# 1449     2390                                          Hip Hop
# 1450     2391                         Super Fresh Cheese Curds
#
#                                  CheeseNameFr  \
# 0                     Sieur de Duplessis (Le)
# 1                         Tomme Le Champ Doré
# 2          Provolone Sette Fette (Tre-Stelle)
# 3                              Geai Bleu (Le)
# 4                                  Gamin (Le)
# 5
# 6
# 7
# 8
# 9
# 10                        Madame Chèvre Elite
# 11                                Leoni-Grana
# 12
# 13
# 14
# 15
# 16
# 17
# 18                                  Madawaska
# 19
# 20                            Cumin Verdelait
# 21
# 22
# 23                            Comox Camembert
# 24                         Provolone (Silani)
# 25                           Ricotta (Silani)
# 26
# 27
# 28
# 29
# ...                                       ...
# 1421                               Gigot (Le)
# 1422                   Fromage Frais Mathurin
# 1423                            Fêta Pénélope
# 1424                          Cornebique (Le)
# 1425                       Affine Bouche (L')
# 1426                       Coq de l'Anse (Le)
# 1427                        Lune de Miel (Le)
# 1428                             Lunatic (Le)
# 1429               Cheddar La Tête sur le Bio
# 1430      Cheddar en grain La Tête sur le Bio
# 1431
# 1432                                Louis Cyr
# 1433  Cheddar (Biobio) - doux, médium et fort
# 1434                           Gouda (Biobio)
# 1435
# 1436                             Dill Cheddar
# 1437                           Garlic Cheddar
# 1438                             Cheese Curds
# 1439         Smoky/Smoke Cheddar (Apple Wood)
# 1440                                   Cancre
# 1441                                  Brigand
# 1442                                 Gavroche
# 1443   Petit frais aux noix et sirop d'érable
# 1444                           Petits caprice
# 1445              Petit frais aux canneberges
# 1446                                 Knoydart
# 1447                                  FRESK-O
# 1448                            Electric Blue
# 1449                                  Hip Hop
# 1450                 Super Fresh Cheese Curds
#
#                    ManufacturerNameEn           ManufacturerNameFr  \
# 0                                         Fromages la faim de loup
# 1                                         Fromages la faim de loup
# 2             Tre Stelle (Arla Foods)
# 3                                         Fromages la faim de loup
# 4                                         Fromages la faim de loup
# 5         Northumberland Co-operative
# 6                      Woolwich Dairy
# 7                      Woolwich Dairy
# 8                      Woolwich Dairy
# 9                      Woolwich Dairy
# 10                     Woolwich Dairy
# 11                        Leoni-Grana                  Leoni-Grana
# 12                Jerseyland Organics
# 13                Jerseyland Organics
# 14                Jerseyland Organics
# 15                Jerseyland Organics
# 16                Jerseyland Organics
# 17                Jerseyland Organics
# 18          Back Forty Artisan Cheese
# 19    Natural Pastures Cheese Company
# 20    Natural Pastures Cheese Company
# 21    Natural Pastures Cheese Company
# 22    Natural Pastures Cheese Company
# 23    Natural Pastures Cheese Company
# 24                Silani Sweet Cheese
# 25                Silani Sweet Cheese
# 26                 Sylvan Star Cheese
# 27        Upper Canada Cheese Company
# 28        Upper Canada Cheese Company
# 29        Balderson Cheese (Parmalat)
# ...                               ...                          ...
# 1421                                         Fromagerie Ruban Bleu
# 1422               Chèvrerie Mathurin           Chèvrerie Mathurin
# 1423               Chèvrerie Mathurin           Chèvrerie Mathurin
# 1424               Chèvrerie Mathurin           Chèvrerie Mathurin
# 1425             Tête sur le Bio (La)         Tête sur le Bio (La)
# 1426             Tête sur le Bio (La)         Tête sur le Bio (La)
# 1427             Tête sur le Bio (La)         Tête sur le Bio (La)
# 1428             Tête sur le Bio (La)         Tête sur le Bio (La)
# 1429             Tête sur le Bio (La)         Tête sur le Bio (La)
# 1430             Tête sur le Bio (La)         Tête sur le Bio (La)
# 1431           Crystal Springs Cheese       Crystal Springs Cheese
# 1432                                           Fromagerie Bergeron
# 1433                          Gattuso                      Gattuso
# 1434                          Gattuso                      Gattuso
# 1435            Coteau Hills Creamery        Coteau Hills Creamery
# 1436              Old School Cheesery          Old School Cheesery
# 1437              Old School Cheesery          Old School Cheesery
# 1438              Old School Cheesery          Old School Cheesery
# 1439              Old School Cheesery          Old School Cheesery
# 1440                                   Fromagerie Au Fond Des Bois
# 1441                                   Fromagerie Au Fond Des Bois
# 1442                                   Fromagerie Au Fond Des Bois
# 1443                                   Fromagerie Au Fond Des Bois
# 1444                                   Fromagerie Au Fond Des Bois
# 1445                                   Fromagerie Au Fond Des Bois
# 1446             Knoydart Farm Cheese         Knoydart Farm Cheese
# 1447                 Latin Foods Inc.             Latin Foods Inc.
# 1448              Blue Harbour Cheese          Blue Harbour Cheese
# 1449              Blue Harbour Cheese          Blue Harbour Cheese
# 1450          The Cheese Factory Ltd.
#
#      ManufacturerProvCode ManufacturingTypeEn ManufacturingTypeFr  \
# 0                      NB           Farmstead            Fermière
# 1                      NB           Farmstead            Fermière
# 2                      ON          Industrial        Industrielle
# 3                      NB           Farmstead            Fermière
# 4                      NB           Farmstead            Fermière
# 5                      NB          Industrial        Industrielle
# 6                      ON          Industrial        Industrielle
# 7                      ON          Industrial        Industrielle
# 8                      ON          Industrial        Industrielle
# 9                      ON          Industrial        Industrielle
# 10                     ON          Industrial        Industrielle
# 11                     AB             Artisan          Artisanale
# 12                     BC           Farmstead            Fermière
# 13                     BC           Farmstead            Fermière
# 14                     BC           Farmstead            Fermière
# 15                     BC           Farmstead            Fermière
# 16                     BC           Farmstead            Fermière
# 17                     BC           Farmstead            Fermière
# 18                     ON             Artisan          Artisanale
# 19                     BC             Artisan          Artisanale
# 20                     BC             Artisan          Artisanale
# 21                     BC             Artisan          Artisanale
# 22                     BC             Artisan          Artisanale
# 23                     BC             Artisan          Artisanale
# 24                     ON          Industrial        Industrielle
# 25                     ON          Industrial        Industrielle
# 26                     AB           Farmstead            Fermière
# 27                     ON           Farmstead            Fermière
# 28                     ON           Farmstead            Fermière
# 29                     ON          Industrial        Industrielle
# ...                   ...                 ...                 ...
# 1421                   QC           Farmstead            Fermière
# 1422                   QC           Farmstead            Fermière
# 1423                   QC           Farmstead            Fermière
# 1424                   QC           Farmstead            Fermière
# 1425                   QC             Artisan          Artisanale
# 1426                   QC             Artisan          Artisanale
# 1427                   QC             Artisan          Artisanale
# 1428                   QC             Artisan          Artisanale
# 1429                   QC             Artisan          Artisanale
# 1430                   QC             Artisan          Artisanale
# 1431                   AB           Farmstead            Fermière
# 1432                   QC          Industrial        Industrielle
# 1433                   QC          Industrial        Industrielle
# 1434                   QC          Industrial        Industrielle
# 1435                   SK             Artisan          Artisanale
# 1436                   AB             Artisan          Artisanale
# 1437                   AB             Artisan          Artisanale
# 1438                   AB             Artisan          Artisanale
# 1439                   AB             Artisan          Artisanale
# 1440                   NB           Farmstead            Fermière
# 1441                   NB           Farmstead            Fermière
# 1442                   NB           Farmstead            Fermière
# 1443                   NB           Farmstead            Fermière
# 1444                   NB           Farmstead            Fermière
# 1445                   NB           Farmstead            Fermière
# 1446                   NS           Farmstead            Fermière
# 1447                   AB          Industrial        Industrielle
# 1448                   NS             Artisan          Artisanale
# 1449                   NS             Artisan          Artisanale
# 1450                   AB             Artisan          Artisanale
#
#                                               WebSiteEn  \
# 0
# 1
# 2                      http://www.trestelle.ca/english/
# 3
# 4
# 5         http://www.northumberlanddairy.ca/e/0001e.cfm
# 6                          http://www.woolwichdairy.com
# 7                          http://www.woolwichdairy.com
# 8                          http://www.woolwichdairy.com
# 9                          http://www.woolwichdairy.com
# 10                         http://www.woolwichdairy.com
# 11
# 12                     http://www.jerseylandorganics.ca
# 13                     http://www.jerseylandorganics.ca
# 14                     http://www.jerseylandorganics.ca
# 15                     http://www.jerseylandorganics.ca
# 16                     http://www.jerseylandorganics.ca
# 17                     http://www.jerseylandorganics.ca
# 18                          http://www.artisancheese.ca
# 19                       http://www.naturalpastures.com
# 20                       http://www.naturalpastures.com
# 21                       http://www.naturalpastures.com
# 22                       http://www.naturalpastures.com
# 23                       http://www.naturalpastures.com
# 24                                 http://www.silani.ca
# 25                                 http://www.silani.ca
# 26                   http://www.sylvanstarcheesefarm.ca
# 27                     http://www.uppercanadacheese.com
# 28                     http://www.uppercanadacheese.com
# 29                        http://www.baldersoncheese.ca
# ...                                                 ...
# 1421
# 1422
# 1423
# 1424
# 1425
# 1426
# 1427
# 1428
# 1429
# 1430
# 1431                    http://crystalspringscheese.com
# 1432           http://www.fromagesbergeron.com/home.php
# 1433                  http://www.biobio.ca/en/home.html
# 1434                  http://www.biobio.ca/en/home.html
# 1435         http://http://www.coteauhillscreamery.com/
# 1436                   http://www.oldschoolcheesery.com
# 1437                   http://www.oldschoolcheesery.com
# 1438                   http://www.oldschoolcheesery.com
# 1439                   http://www.oldschoolcheesery.com
# 1440  http://http://www.aufonddesbois.com/English/in...
# 1441  http://http://www.aufonddesbois.com/English/in...
# 1442  http://http://www.aufonddesbois.com/English/in...
# 1443  http://http://www.aufonddesbois.com/English/in...
# 1444  http://http://www.aufonddesbois.com/English/in...
# 1445  http://http://www.aufonddesbois.com/English/in...
# 1446                http://https://www.knoydartfarm.org
# 1447                             http://www.fresk-o.com
# 1448                   http://www.blueharbourcheese.com
# 1449                   http://www.blueharbourcheese.com
# 1450                     http://www.thecheesefactory.ca
#
#                                               WebSiteFr  ... Organic  \
# 0                                                        ...       0
# 1                                                        ...       0
# 2                     http://www.trestelle.ca/francais/  ...       0
# 3                                                        ...       0
# 4                                                        ...       1
# 5         http://www.northumberlanddairy.ca/f/0001f.cfm  ...       0
# 6              http://www.woolwichdairy.com/french.aspx  ...       0
# 7              http://www.woolwichdairy.com/french.aspx  ...       0
# 8              http://www.woolwichdairy.com/french.aspx  ...       0
# 9              http://www.woolwichdairy.com/french.aspx  ...       0
# 10             http://www.woolwichdairy.com/french.aspx  ...       0
# 11                                                       ...       0
# 12                                                       ...       1
# 13                                                       ...       1
# 14                                                       ...       1
# 15                                                       ...       1
# 16                                                       ...       1
# 17                                                       ...       1
# 18                                                       ...       0
# 19                                                       ...       0
# 20                                                       ...       0
# 21                                                       ...       0
# 22                                                       ...       0
# 23                                                       ...       0
# 24                                                       ...       0
# 25                                                       ...       0
# 26                                                       ...       0
# 27                                                       ...       0
# 28                                                       ...       0
# 29                http://www.baldersoncheese.ca/french/  ...       0
# ...                                                 ...  ...     ...
# 1421                           http://www.rubanbleu.net  ...       0
# 1422                   http://www.chevreviemathurin.com  ...       0
# 1423                   http://www.chevreviemathurin.com  ...       0
# 1424                   http://www.chevreviemathurin.com  ...       0
# 1425                      http://www.latetesurlebio.com  ...       1
# 1426                      http://www.latetesurlebio.com  ...       1
# 1427                      http://www.latetesurlebio.com  ...       1
# 1428                      http://www.latetesurlebio.com  ...       1
# 1429                      http://www.latetesurlebio.com  ...       1
# 1430                      http://www.latetesurlebio.com  ...       1
# 1431                                                     ...       0
# 1432                    http://www.fromagesbergeron.com  ...       0
# 1433               http://www.biobio.ca/fr/accueil.html  ...       1
# 1434               http://www.biobio.ca/fr/accueil.html  ...       1
# 1435                                                     ...       0
# 1436                                                     ...       0
# 1437                                                     ...       0
# 1438                                                     ...       0
# 1439                                                     ...       0
# 1440  http://http://www.aufonddesbois.com/Francais/i...  ...       0
# 1441  http://http://www.aufonddesbois.com/Francais/i...  ...       0
# 1442  http://http://www.aufonddesbois.com/Francais/i...  ...       0
# 1443  http://http://www.aufonddesbois.com/Francais/i...  ...       0
# 1444  http://http://www.aufonddesbois.com/Francais/i...  ...       0
# 1445  http://http://www.aufonddesbois.com/Francais/i...  ...       0
# 1446                                                     ...       1
# 1447                                                     ...       0
# 1448                                                     ...       0
# 1449                                                     ...       0
# 1450                                                     ...       0
#
#         CategoryTypeEn   CategoryTypeFr MilkTypeEn MilkTypeFr  \
# 0          Firm Cheese       Pâte ferme        Ewe     Brebis
# 1     Semi-soft Cheese  Pâte demi-ferme        Cow      Vache
# 2          Firm Cheese       Pâte ferme        Cow      Vache
# 3       Veined Cheeses   Pâte persillée        Cow      Vache
# 4     Semi-soft Cheese  Pâte demi-ferme        Cow      Vache
# 5         Fresh Cheese     Pâte fraîche        Cow      Vache
# 6          Soft Cheese       Pâte molle       Goat     Chèvre
# 7          Firm Cheese       Pâte ferme       Goat     Chèvre
# 8     Semi-soft Cheese  Pâte demi-ferme       Goat     Chèvre
# 9          Soft Cheese       Pâte molle       Goat     Chèvre
# 10        Fresh Cheese     Pâte fraîche       Goat     Chèvre
# 11         Hard Cheese        Pâte dure        Cow      Vache
# 12    Semi-soft Cheese  Pâte demi-ferme        Cow      Vache
# 13    Semi-soft Cheese  Pâte demi-ferme        Cow      Vache
# 14         Hard Cheese        Pâte dure        Cow      Vache
# 15         Soft Cheese       Pâte molle        Cow      Vache
# 16    Semi-soft Cheese  Pâte demi-ferme       Goat     Chèvre
# 17         Soft Cheese       Pâte molle       Goat     Chèvre
# 18         Soft Cheese       Pâte molle        Ewe     Brebis
# 19         Firm Cheese       Pâte ferme        Cow      Vache
# 20         Firm Cheese       Pâte ferme        Cow      Vache
# 21         Firm Cheese       Pâte ferme        Cow      Vache
# 22         Firm Cheese       Pâte ferme        Cow      Vache
# 23         Soft Cheese       Pâte molle        Cow      Vache
# 24         Firm Cheese       Pâte ferme        Cow      Vache
# 25        Fresh Cheese     Pâte fraîche        Cow      Vache
# 26         Firm Cheese       Pâte ferme        Cow      Vache
# 27    Semi-soft Cheese  Pâte demi-ferme        Cow      Vache
# 28         Soft Cheese       Pâte molle        Cow      Vache
# 29         Firm Cheese       Pâte ferme        Cow      Vache
# ...                ...              ...        ...        ...
# 1421  Semi-soft Cheese  Pâte demi-ferme        Ewe     Brebis
# 1422      Fresh Cheese     Pâte fraîche       Goat     Chèvre
# 1423  Semi-soft Cheese  Pâte demi-ferme       Goat     Chèvre
# 1424       Soft Cheese       Pâte molle       Goat     Chèvre
# 1425       Firm Cheese       Pâte ferme        Cow      Vache
# 1426       Firm Cheese       Pâte ferme        Cow      Vache
# 1427  Semi-soft Cheese  Pâte demi-ferme        Cow      Vache
# 1428  Semi-soft Cheese  Pâte demi-ferme        Cow      Vache
# 1429       Firm Cheese       Pâte ferme        Cow      Vache
# 1430      Fresh Cheese     Pâte fraîche        Cow      Vache
# 1431  Semi-soft Cheese  Pâte demi-ferme       Goat     Chèvre
# 1432
# 1433       Firm Cheese       Pâte ferme        Cow      Vache
# 1434       Firm Cheese       Pâte ferme        Cow      Vache
# 1435       Soft Cheese       Pâte molle        Cow      Vache
# 1436       Firm Cheese       Pâte ferme        Cow      Vache
# 1437       Firm Cheese       Pâte ferme        Cow      Vache
# 1438
# 1439       Firm Cheese       Pâte ferme        Cow      Vache
# 1440  Semi-soft Cheese  Pâte demi-ferme       Goat     Chèvre
# 1441  Semi-soft Cheese  Pâte demi-ferme       Goat     Chèvre
# 1442       Soft Cheese       Pâte molle       Goat     Chèvre
# 1443       Soft Cheese       Pâte molle       Goat     Chèvre
# 1444  Semi-soft Cheese  Pâte demi-ferme       Goat     Chèvre
# 1445      Fresh Cheese     Pâte fraîche       Goat     Chèvre
# 1446       Hard Cheese        Pâte dure        Cow      Vache
# 1447      Fresh Cheese     Pâte fraîche        Cow      Vache
# 1448    Veined Cheeses   Pâte persillée        Ewe     Brebis
# 1449  Semi-soft Cheese  Pâte demi-ferme        Ewe     Brebis
# 1450      Fresh Cheese     Pâte fraîche        Cow      Vache
#
#      MilkTreatmentTypeEn MilkTreatmentTypeFr   RindTypeEn      RindTypeFr  \
# 0               Raw Milk            Lait cru  Washed Rind    Croûte lavée
# 1               Raw Milk            Lait cru  Washed Rind    Croûte lavée
# 2            Pasteurized          Pasteurisé
# 3               Raw Milk            Lait cru
# 4               Raw Milk            Lait cru  Washed Rind    Croûte lavée
# 5            Pasteurized          Pasteurisé
# 6            Pasteurized          Pasteurisé  Bloomy Rind  Croûte fleurie
# 7            Pasteurized          Pasteurisé
# 8            Pasteurized          Pasteurisé
# 9            Pasteurized          Pasteurisé
# 10           Pasteurized          Pasteurisé
# 11              Raw Milk            Lait cru
# 12              Raw Milk            Lait cru
# 13              Raw Milk            Lait cru
# 14              Raw Milk            Lait cru
# 15              Raw Milk            Lait cru
# 16              Raw Milk            Lait cru
# 17              Raw Milk            Lait cru
# 18              Raw Milk            Lait cru  Bloomy Rind  Croûte fleurie
# 19           Pasteurized          Pasteurisé
# 20           Pasteurized          Pasteurisé
# 21           Pasteurized          Pasteurisé
# 22           Pasteurized          Pasteurisé
# 23           Pasteurized          Pasteurisé
# 24           Pasteurized          Pasteurisé
# 25           Pasteurized          Pasteurisé      No Rind     Sans croûte
# 26           Pasteurized          Pasteurisé
# 27           Pasteurized          Pasteurisé  Washed Rind    Croûte lavée
# 28           Pasteurized          Pasteurisé  Bloomy Rind  Croûte fleurie
# 29           Pasteurized          Pasteurisé      No Rind     Sans croûte
# ...                  ...                 ...          ...             ...
# 1421                                          Washed Rind    Croûte lavée
# 1422                                              No Rind     Sans croûte
# 1423
# 1424                                              No Rind     Sans croûte
# 1425           Thermised            Thermisé  Washed Rind    Croûte lavée
# 1426           Thermised            Thermisé  Washed Rind    Croûte lavée
# 1427           Thermised            Thermisé  Washed Rind    Croûte lavée
# 1428           Thermised            Thermisé  Washed Rind    Croûte lavée
# 1429         Pasteurized          Pasteurisé      No Rind     Sans croûte
# 1430         Pasteurized          Pasteurisé      No Rind     Sans croûte
# 1431         Pasteurized          Pasteurisé      No Rind     Sans croûte
# 1432
# 1433           Thermised            Thermisé      No Rind     Sans croûte
# 1434           Thermised            Thermisé      No Rind     Sans croûte
# 1435         Pasteurized          Pasteurisé
# 1436         Pasteurized          Pasteurisé      No Rind     Sans croûte
# 1437         Pasteurized          Pasteurisé      No Rind     Sans croûte
# 1438
# 1439         Pasteurized          Pasteurisé      No Rind     Sans croûte
# 1440         Pasteurized          Pasteurisé  Washed Rind    Croûte lavée
# 1441         Pasteurized          Pasteurisé
# 1442         Pasteurized          Pasteurisé
# 1443         Pasteurized          Pasteurisé
# 1444         Pasteurized          Pasteurisé
# 1445         Pasteurized          Pasteurisé
# 1446         Pasteurized          Pasteurisé
# 1447         Pasteurized          Pasteurisé
# 1448           Thermised            Thermisé
# 1449           Thermised            Thermisé  Washed Rind    Croûte lavée
# 1450         Pasteurized          Pasteurisé      No Rind     Sans croûte
#
#                  LastUpdateDate
# 0     2016-02-03T11:04:24-05:00
# 1     2016-02-03T11:04:24-05:00
# 2     2016-02-03T11:04:28-05:00
# 3     2016-02-03T11:04:24-05:00
# 4     2016-02-03T11:04:24-05:00
# 5     2016-02-03T11:04:25-05:00
# 6     2016-02-03T11:04:25-05:00
# 7     2016-02-03T11:04:25-05:00
# 8     2016-02-03T11:04:25-05:00
# 9     2016-02-03T11:04:25-05:00
# 10    2016-02-03T11:04:25-05:00
# 11    2016-02-03T11:04:25-05:00
# 12    2016-02-03T11:04:25-05:00
# 13    2016-02-03T11:04:25-05:00
# 14    2016-02-03T11:04:25-05:00
# 15    2016-02-03T11:04:25-05:00
# 16    2016-02-03T11:04:25-05:00
# 17    2016-02-03T11:04:25-05:00
# 18    2016-02-03T11:04:25-05:00
# 19    2016-02-03T11:04:25-05:00
# 20    2016-02-03T11:04:25-05:00
# 21    2016-02-03T11:04:25-05:00
# 22    2016-02-03T11:04:25-05:00
# 23    2016-02-03T11:04:25-05:00
# 24    2016-02-03T11:04:26-05:00
# 25    2016-02-03T11:04:26-05:00
# 26    2016-02-03T11:04:26-05:00
# 27    2016-02-03T11:04:26-05:00
# 28    2016-02-03T11:04:26-05:00
# 29    2017-01-18T14:08:19-05:00
# ...                         ...
# 1421  2016-02-03T11:04:40-05:00
# 1422  2016-02-03T11:05:19-05:00
# 1423  2016-02-03T11:05:19-05:00
# 1424  2016-02-03T11:05:19-05:00
# 1425  2016-02-03T11:05:19-05:00
# 1426  2016-02-03T11:05:19-05:00
# 1427  2016-02-03T11:05:19-05:00
# 1428  2016-02-03T11:05:19-05:00
# 1429  2016-02-03T11:05:19-05:00
# 1430  2016-02-03T11:05:19-05:00
# 1431  2016-02-03T11:05:19-05:00
# 1432  2016-02-03T11:04:37-05:00
# 1433  2016-04-27T09:11:51-05:00
# 1434  2016-04-27T09:10:58-05:00
# 1435  2017-01-30T13:41:47-05:00
# 1436  2017-03-13T15:42:27-05:00
# 1437  2017-03-16T16:04:04-05:00
# 1438  2017-03-16T16:17:45-05:00
# 1439  2018-05-22T13:57:26-05:00
# 1440  2018-05-24T15:35:32-05:00
# 1441  2018-05-24T15:35:52-05:00
# 1442  2018-05-24T14:34:55-05:00
# 1443  2018-05-24T15:36:22-05:00
# 1444  2018-05-24T15:29:01-05:00
# 1445  2018-05-24T15:33:30-05:00
# 1446  2018-06-11T13:55:28-05:00
# 1447  2018-06-11T14:08:22-05:00
# 1448  2019-02-19T13:05:42-05:00
# 1449  2019-02-19T13:14:16-05:00
# 1450  2019-03-01T14:01:18-05:00
#
# [1451 rows x 30 columns]

# %% [markdown]
# ## Queries to try
#
# - Milk types by English and French
# - All cheeses made in the province of Manitoba
# - All cheeses which have a website in English or French
# - All cheeses made with milk from ewes
# - All pasteurized cheeses made in Ontario
# - Names of cheese (French and English) produced in Farmsteads

# %% [markdown]
# ## Loading JSON files into MySQL's document store
#
# Now we're going to use the document store in MySQL. Although MySQL started as a relational database system, this document store gives you the ability to use NoSQL inside MySQL.
#
# This is optional, but we can create a separate schema to separate our two datasets.
# To get setup, go into SQL mode in the MySQL shell (if you aren't there already)
#
# `\sql
# CREATE DATABASE json_sample;
# \use json_sample
# \py
# `
#
# Then create a Collection
#
# `db.create_collection('cheese')`
#
# To use the document store, we need to use a different set of libraries. Instead of the MySQL Connector, we will be using the MySQL X Protocol, which [is also produced by MySQL](https://dev.mysql.com/doc/x-devapi-userguide).
#
# The process is similar. Instead of opening a connection, we will open a session. We will use this to access the schema, and then the collection.
#
# We'll begin by adding data from our DataFrame to the collection as a series of documents.

# %%
import mysqlx

jsonSession = mysqlx.get_session({'host': 'localhost', 'port':'33060', 'user':'root','password':'yourpasswordhere'})

mySchema = jsonSession.get_schema('json_sample')

myCollection = mySchema.get_collection('cheese')

# first we need to write a document to our collection
# Notice that we have to reshape the DataFrame back into a dictionary
addResult = myCollection.add(cheeseFrame.to_dict(orient="records")).execute()

# check to make sure something actually happened
print(addResult.get_affected_items_count())
# Out:
# 1451

# %% [markdown]
# ## Querying using MySQL shell
#
# The basis of the NoSQL query is the find method.For example, to return everything in the collection (which is called "cheese"), you can type
#
# `db.cheese.find()`
#
# To do a projection, you can use the `fields()` method:
#
# `db.cheese.find().fields(["CheeseId", "CheeseNameEn"])`
#
# To do a selection, you can pass a parameter to the `find()` method:
#
# `db.cheese.find("ManufacturingTypeEn = 'Artisan'")`
#
# You can also use the bind() method to _parameterize_ the query. This allows a query to be submitted without all of the information you want in the filters.
#
# It is also possible to query the document store programmatically via Python.
#
# Here is an example:

# %%
print(myCollection.count())
queryResult = myCollection.find("ManufacturerProvCode = 'NB'").execute()

rows = queryResult.fetch_all()

for row in rows:
    print("%s %s %s" %(row.CheeseNameEn, row.CheeseNameFr, row.ManufacturerProvCode))
# Out:
# 1451
#  Sieur de Duplessis (Le) NB
#  Tomme Le Champ Doré NB
#  Geai Bleu (Le) NB
#  Gamin (Le) NB
# Paneer (Northumberland Co-operative)  NB
#  Cheddar (Blancs d'Arcadie) NB
#  Peppercorn (Blancs d'Arcadie) NB
#  Tomme Blanche NB
#  Tintamarre (Le) NB
#  Petit Bayou (Le) NB
#  Choupet's (Le) NB
#  Saint Manu (Le) NB
#  Faisselles (Les) NB
# Cheddar  NB
#  Fromage en grain NB
#  Barbizon (Le) NB
#  Cabriolet (Le) NB
#  Acadiac (L') NB
#  Petit Frais (Le) NB
#  Forban (Le) NB
# Feta  NB
#  Poivroux (Le) NB
#  Petit lardé (Le) NB
# Cancre Cancre NB
# Brigand Brigand NB
# Gavroche Gavroche NB
# Petit frais aux noix et sirop d'érable Petit frais aux noix et sirop d'érable NB
# Petits caprice Petits caprice NB
# Petit frais aux canneberges Petit frais aux canneberges NB
